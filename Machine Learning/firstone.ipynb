# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pit
import seaborn as sns

# %%
churn_data = pd.read_csv('C:\Python_works\Machine Learning\CEHHbInToW.csv')
churn_data
# Out:
#       RowNumber  CustomerId Firstname  Lastname  CreditScore Geography  \
# 0             1    15634602     Grace  Williams          619    France
# 1             2    15647311     David     Jones          608     Spain
# 2             3    15619304      Hank  Williams          502    France
# 3             4    15701354       Eva    Taylor          699    France
# 4             5    15737888     Grace    Miller          850     Spain
# ...         ...         ...       ...       ...          ...       ...
# 9995       9996    15606229     Grace    Garcia          771    France
# 9996       9997    15569892      Jack    Garcia          516    France
# 9997       9998    15584532     Carol   Johnson          709    France
# 9998       9999    15682355      Jack    Garcia          772   Germany
# 9999      10000    15628319       Eva    Garcia          792    France
#
#       Gender   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# ...

# %%
churn_data.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Firstname', 'Lastname', 'CreditScore',
#        'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts',
#        'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
churn_data.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Firstname           object
# Lastname            object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                float64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
balance = churn_data['Exited']
balance
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
balance_count = balance.value_counts()
balance_count
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
balance_count.plot(kind='bar')
# Out:
# <Axes: ylabel='count'>
